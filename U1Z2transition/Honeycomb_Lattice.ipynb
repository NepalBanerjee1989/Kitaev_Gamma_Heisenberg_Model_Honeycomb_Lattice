# %%
#########################################
# Plotting the data from MC calculation #
#########################################
import numpy as np
import matplotlib.pyplot as plt
data0 =np.loadtxt('HSO')
#data1 =np.loadtxt('HSO_6')
#data2 =np.loadtxt('HSO_8')
#data3 =np.loadtxt('HSO_10')
#data4 =np.loadtxt('HSO_6')
#data5 =np.loadtxt('HSO_10_now')
#data6 =np.loadtxt('HSO_4')
plt.figure(20)
#########################################
######### Magnetization vs T ############
#########################################
font1={'family':'serif','color':'blue','size':10}
font2={'family':'serif','color':'darkred','size':10}
plt.plot(data0[:,0],data0[:,1],'ro-',label='4x4',lw=1)
#plt.plot(data1[:47,0],data1[:47,4],'bo-',label='6x6',lw=1)
#plt.plot(data2[:47,0],data2[:47,4],'mo-',label='8x8',lw=1)
#plt.plot(data3[:47,0],data3[:47,4],'go-',label='10x10',lw=1)
#plt.plot(data4[:,0],data4[:,1],'mo-',label='6x6',lw=1)
#plt.plot(data5[:,0],data5[:,1],'go-',label='10x10',lw=1)
#plt.plot(data6[:,0],data6[:,1],'ko-',label='4x4',lw=1)
##########################################
##########################################
plt.xlabel("Average Pulse",fontdict=font1,fontsize=20)
plt.ylabel("Calorie Burnage",fontdict=font1,fontsize=20)
#Set the font size of xticks
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('T')
plt.ylabel('m')
plt.legend() 
plt.show
plt.savefig('HK.png',bbox_inches = 'tight')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 19
#      17 font1={'family':'serif','color':'blue','size':10}
#      18 font2={'family':'serif','color':'darkred','size':10}
# ---> 19 plt.plot(data0[:,0],data0[:,1],'ro-',label='4x4',lw=1)
#      20 #plt.plot(data1[:47,0],data1[:47,4],'bo-',label='6x6',lw=1)
#      21 #plt.plot(data2[:47,0],data2[:47,4],'mo-',label='8x8',lw=1)
#      22 #plt.plot(data3[:47,0],data3[:47,4],'go-',label='10x10',lw=1)
#    (...)
#      26 ##########################################
#      27 ##########################################
#      28 plt.xlabel("Average Pulse",fontdict=font1,fontsize=20)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
